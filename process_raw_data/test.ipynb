# %%
import os
import pydicom
from pathlib import Path

# === Define paths ===
reference_root = Path('/datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100')  # Target: where subfolders are written to
source_root = Path('/datastore01/user-storage/y.zezhang/2025_high_dose_project/data/high_dose_reg_PriPrj_ScaPrj_RegCT_DICOM')        # Contains RegCT and PriPrj folders
template_dir = Path('/datastore01/user-storage/y.zezhang/2025_high_dose_project/supporting_file')     # Contains ct.hct and .h00 template

# === Load templates ===
with open(template_dir / 'mod_proj_da2130s100_obj_01927022_d1.h00', 'r') as f:
    h00_template = f.read()

with open(template_dir / 'ct.hct', 'r') as f:
    hct_template = f.read()

# === Process each reference subfolder ===
for subfolder in reference_root.iterdir():
    
    if not subfolder.is_dir():
        continue

    ref_id = subfolder.name
    
    # === Locate corresponding RegCT and PriPrj folders ===
    regct_folder = next((source_root / f for f in os.listdir(source_root)
                         if 'RegCT' in f and ref_id in f and (source_root / f).is_dir()), None)
    prj_folder = next((source_root / f for f in os.listdir(source_root)
                       if 'PriPrj' in f and ref_id in f and (source_root / f).is_dir()), None)
    
    if regct_folder is None or prj_folder is None:
        print(f"Skipping {ref_id}: missing RegCT or PriPrj folder.")
        continue

    # === Read any .dcm file from PriPrj and RegCT folders ===
    def read_first_dcm(folder):
        for file in os.listdir(folder):
            if file.lower().endswith('.dcm'):
                try:
                    return pydicom.dcmread(folder / file)
                except Exception as e:
                    print(f"Failed to read DICOM in {folder}: {e}")
                    return None
        return None

    prj_dcm = read_first_dcm(prj_folder)
    regct_dcm = read_first_dcm(regct_folder)

    
    if prj_dcm is None or regct_dcm is None:
        print(f"Skipping {ref_id}: could not read DICOMs.")
        continue

    # === Get needed DICOM fields ===
    try:
        num_frames = int(prj_dcm[0x0028, 0x0008].value)  # Number of Frames in Rotation
        prj_rows = int(prj_dcm.Rows)
        prj_cols = int(prj_dcm.Columns)
        start_angle=float(prj_dcm[0x0054,0x0022][0][0x0054,0x0200].value)
        scan_angle= float(prj_dcm[0x0054,0x0052][0][0x0018,0x1143].value)
        
    except:
        print(f"Skipping {ref_id}: missing PriPrj metadata.")
        continue

    try:
        regct_rows = int(regct_dcm.Rows)
        regct_cols=int(regct_dcm.Columns)
        slice_thickness=float(regct_dcm[0x0018,0x0050].value)
    except:
        print(f"Skipping {ref_id}: missing RegCT metadata.")
        continue

    # === Count .dcm files in RegCT folder ===
    regct_dcm_count = sum(1 for f in os.listdir(regct_folder) if f.lower().endswith('.dcm'))



    # === Modify .h00 content ===
    h00_modified = h00_template
    h00_modified = h00_modified.replace(
        '!name of data file := mod_proj_da2130s100_obj_01927022_d1.a00',
        f'!name of data file := {ref_id}.a00'
    )
    h00_modified = h00_modified.replace(
        'patient name := SMC_mod_proj_da2130s100_obj_01927022_d1.a00',
        f'patient name := {ref_id}.a00'
    )
    h00_modified = h00_modified.replace(
        '!total number of images := 30',
        f'!total number of images := {num_frames}'
    )
    h00_modified = h00_modified.replace(
        '!matrix size [1] := 64',
        f'!matrix size [1] := {prj_rows}'
    )
    h00_modified = h00_modified.replace(
        '!matrix size [2] := 64',
        f'!matrix size [2] := {prj_cols}'
    )
    h00_modified = h00_modified.replace(
        'start angle := 225.350',
        f'start angle := {start_angle}'
    )
    h00_modified = h00_modified.replace(
        '!number of projections := 30',
        f'!number of projections := {num_frames}'
    )
    h00_modified = h00_modified.replace(
        '!number of images/energy window := 30',
        f'!number of images/energy window := {num_frames}'
    )
    h00_modified = h00_modified.replace(
        'image duration (sec) := 30.000',
        f'image duration (sec) := {num_frames}'
    )
    h00_modified = h00_modified.replace(
        'scaling factor (mm/pixel) [1] := 6.800',
        f'scaling factor (mm/pixel) [1] := {435.0090/prj_rows}'
    )
    h00_modified = h00_modified.replace(
        'scaling factor (mm/pixel) [2] := 6.800',
        f'scaling factor (mm/pixel) [1] := {435.0090/prj_cols}'
    )
    h00_modified = h00_modified.replace(
        'scaling factor (mm/pixel) [3] := 6.800',
        f'scaling factor (mm/pixel) [3] := {(204/num_frames)*(scan_angle/180)}'
    )
    h00_modified = h00_modified.replace(
        '!extent of rotation := 180',
        f'!extent of rotation := {scan_angle}'
    )
    
    
    # === Modify .hct content ===
    hct_modified = hct_template
    hct_modified = hct_modified.replace(
        '!total number of images := 64',
        f'!total number of images := {regct_dcm_count}'
    )
    hct_modified = hct_modified.replace(
        '!matrix size [1] := 128',
        f'!matrix size [1] := {regct_rows}'
    )
    hct_modified = hct_modified.replace(
        '!matrix size [2] := 128',
        f'!matrix size [2] := {regct_cols}'
    )
    hct_modified = hct_modified.replace(
        '!matrix size [3] := 64',
        f'!matrix size [3] := {regct_dcm_count}'
    )
    hct_modified = hct_modified.replace(
        'scaling factor (mm/pixel) [1] := 3.4',
        f'scaling factor (mm/pixel) [1] := {435.1606/regct_rows}'
    )
    hct_modified = hct_modified.replace(
        'scaling factor (mm/pixel) [2] := 3.4',
        f'scaling factor (mm/pixel) [2] := {435.1606/regct_cols}'
    )
    hct_modified = hct_modified.replace(
        'scaling factor (mm/pixel) [3] := 6.8',
        f'scaling factor (mm/pixel) [3] := {float(regct_dcm[0x0018,0x0050].value)}'
    )
    hct_modified = hct_modified.replace(
        '!number of images/energy window := 64',
        f'!number of images/energy window := {regct_dcm_count}'
    )
    
    # === Save modified files ===
    h00_path = subfolder / f"{ref_id}.h00"
    hct_path = subfolder / f"{ref_id}.hct"

    with open(h00_path, 'w') as f:
        f.write(h00_modified)

    with open(hct_path, 'w') as f:
        f.write(hct_modified)

    print(f"Processed {ref_id}: .h00 and .hct written to {subfolder}")
# Out:
# Processed 01004358: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/01004358
# Processed 01424087: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/01424087
# Processed 01893473: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/01893473
# Processed 02668037: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/02668037
# Processed 02749222: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/02749222
# Processed 03328459: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/03328459
# Processed 03515223: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/03515223
# Processed 05043200: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/05043200
# Processed 05874747: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/05874747
# Processed 06151490: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/06151490
# Processed 06801870: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/06801870
# Processed 07073416: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/07073416
# Processed 07995008: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/07995008
# Processed 08036279: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/08036279
# Processed 08818648: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/08818648
# Processed 10700106: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/10700106
# Processed 11011176: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/11011176
# Processed 11680244: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/11680244
# Processed 11860813: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/11860813
# Processed 13623780: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/13623780
# Processed 13731149: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/13731149
# Processed 14387500: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/14387500
# Processed 15701689: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/15701689
# Processed 15704064: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/15704064
# Processed 15768997: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/15768997
# Processed 19642661: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/19642661
# Processed 20957183: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/20957183
# Processed 20983911: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/20983911
# Processed 21304885: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/21304885
# Processed 22229736: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/22229736
# Processed 23278942: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/23278942
# Processed 23772210: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/23772210
# Processed 24207384: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/24207384
# Processed 26935265: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/26935265
# Processed 27965981: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/27965981
# Processed 28070170: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/28070170
# Processed 31709787: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/31709787
# Processed 34274011: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/34274011
# Processed 34387922: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/34387922
# Processed 35207735: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/35207735
# Processed 35338825: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/35338825
# Processed 35500028: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/35500028
# Processed 35983551: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/35983551
# Processed 37194727: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/37194727
# Processed 37588745: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/37588745
# Processed 37642479: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/37642479
# Processed 39814901: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/39814901
# Processed 40023267: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/40023267
# Processed 40212603: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/40212603
# Processed 43251571: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/43251571
# Processed 43844415: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/43844415
# Processed 45996986: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/45996986
# Processed 46316925: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/46316925
# Processed 47997779: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/47997779
# Processed 48010549: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/48010549
# Processed 48015273: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/48015273
# Processed 48711463: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/48711463
# Processed 49187639: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/49187639
# Processed 49260263: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/49260263
# Processed 50398925: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/50398925
# Processed 51282695: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/51282695
# Processed 51395359: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/51395359
# Processed 52383455: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/52383455
# Processed 52481505: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/52481505
# Processed 52686932: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/52686932
# Processed 53361707: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/53361707
# Processed 55311648: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/55311648
# Processed 56741195: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/56741195
# Processed 57206600: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/57206600
# Processed 57834053: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/57834053
# Processed 58302549: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/58302549
# Processed 58543264: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/58543264
# Processed 59170133: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/59170133
# Processed 59285951: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/59285951
# Processed 59632159: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/59632159
# Processed 60066121: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/60066121
# Processed 60488763: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/60488763
# Processed 60489927: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/60489927
# Processed 60724306: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/60724306
# Processed 61185879: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/61185879
# Processed 61193563: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/61193563
# Processed 62212947: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/62212947
# Processed 64248640: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/64248640
# Processed 64499495: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/64499495
# Processed 65561718: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/65561718
# Processed 65596111: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/65596111
# Processed 67942256: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/67942256
# Processed 68859589: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/68859589
# Processed 73026656: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/73026656
# Processed 73961373: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/73961373
# Processed 74013364: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/74013364
# Processed 74966661: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/74966661
# Processed 76851099: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/76851099
# Processed 77318459: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/77318459
# Processed 77454526: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/77454526
# Processed 77783514: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/77783514
# Processed 77874073: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/77874073
# Processed 79434864: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/79434864
# Processed 79452385: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/79452385
# Processed 79884491: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/79884491
# Processed 79974869: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/79974869
# Processed 79992044: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/79992044
# Processed 80179296: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/80179296
# Processed 80527293: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/80527293
# Processed 80842217: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/80842217
# Processed 80951405: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/80951405
# Processed 81107800: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/81107800
# Processed 82139198: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/82139198
# Processed 82616055: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/82616055
# Processed 83463199: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/83463199
# Processed 83891744: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/83891744
# Processed 85256235: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/85256235
# Processed 87200955: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/87200955
# Processed 87751690: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/87751690
# Processed 88158855: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/88158855
# Processed 88950249: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/88950249
# Processed 90028238: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/90028238
# Processed 90775602: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/90775602
# Processed 93064335: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/93064335
# Processed 94535883: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/94535883
# Processed 95223667: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/95223667
# Processed 96068998: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/96068998
# Processed 96503138: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/96503138
# Processed 96866538: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/96866538
# Processed 97128740: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/97128740
# Processed 97136374: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/97136374
# Processed 98895749: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/98895749
# Processed 99504966: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/99504966
# Processed 99572086: .h00 and .hct written to /datastore01/user-storage/y.zezhang/2025_high_dose_project/data/projection/hl/dose_level_100/99572086

# %%
import numpy as np
import os
import re


def binomial_subsampling(proj_data, prob):
    proj_data = np.asarray(proj_data)
    int_data = proj_data.astype(np.int32)  
    subsampled = np.zeros_like(int_data)
    mask = int_data > 0
    subsampled[mask] = np.random.binomial(int_data[mask], 1 - prob)
    return subsampled.astype(np.float32)  





proj_data=[100,100,100,100,100]
prob=0.5

# %%
binomial_subsampling(proj_data, prob)
# Out:
# array([49., 57., 52., 47., 49.], dtype=float32)
